# %%
### Importing GIS Libraries
import geopandas as gpd
import plotly.graph_objects as go

import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
project_dir = r'C:\Users\Zuzanna Kabulska\Documents\Omdena'
df_2018 = pd.read_csv(os.path.join(project_dir, 'Datasets\\Neighborhood_Prioritization_Map_2018.csv'))

# %%
df_2018.head()
# Out:
#   Ntacode                                         Ntaname  \
# 0    BK09                    Brooklyn Heights-Cobble Hill
# 1    BK17  Sheepshead Bay-Gerritsen Beach-Manhattan Beach
# 2    BK19                                  Brighton Beach
# 3    BK21                            Seagate-Coney Island
# 4    BK23                                   West Brighton
#
#   Food Insecurity Rate_2018  Food Insecurity Rate_2018_rank  \
# 0                     7.78%                             176
# 1                    12.80%                             100
# 2                    19.40%                              37
# 3                    26.04%                               7
# 4                    14.72%                              81
#
#    Adj Weighted Score December 2020 unemployment rate 2018  \
# 0                6.31                                5.08%
# 1                7.57                                9.68%
# 2                7.30                                8.58%
# ...

# %%
geo_df = gpd.read_file(os.path.join(project_dir, 'Datasets\\nta_2010_map.geojson'))

# %%
geo_df.head()
# Out:
#   ntacode     shape_area county_fips                             ntaname  \
# 0    QN08   77412747.756         081                          St. Albans
# 1    BK50  82089678.5561         047                            Canarsie
# 2    BX41   14716710.849         005                          Mount Hope
# 3    BK68  16482821.6487         047                         Fort Greene
# 4    QN38  38835920.1944         081  Pomonok-Flushing Heights-Hillcrest
#
#       shape_leng boro_name boro_code  \
# 0  45401.3169155    Queens         4
# 1  43703.6099368  Brooklyn         3
# 2  18937.2480746     Bronx         2
# 3  19825.5208594  Brooklyn         3
# 4  30731.4196253    Queens         4
#
#                                             geometry
# 0  MULTIPOLYGON (((-73.75205 40.70523, -73.75174 ...
# 1  MULTIPOLYGON (((-73.88834 40.64671, -73.88835 ...
# 2  MULTIPOLYGON (((-73.89561 40.85457, -73.89662 ...
# 3  MULTIPOLYGON (((-73.96939 40.69608, -73.96938 ...
# ...

# %%
kings_map = geo_df[geo_df["county_fips"]=="047"]

# %%
kings_map.head()
# Out:
#    ntacode     shape_area county_fips                   ntaname  \
# 1     BK50  82089678.5561         047                  Canarsie
# 3     BK68  16482821.6487         047               Fort Greene
# 6     BK44  27379161.6062         047                   Madison
# 9     BK77  24927927.3355         047            Bushwick North
# 10    BK41  15893333.8214         047  Kensington-Ocean Parkway
#
#        shape_leng boro_name boro_code  \
# 1   43703.6099368  Brooklyn         3
# 3   19825.5208594  Brooklyn         3
# 6   26237.2579388  Brooklyn         3
# 9   26321.6271006  Brooklyn         3
# 10  20800.7475279  Brooklyn         3
#
#                                              geometry
# 1   MULTIPOLYGON (((-73.88834 40.64671, -73.88835 ...
# 3   MULTIPOLYGON (((-73.96939 40.69608, -73.96938 ...
# 6   MULTIPOLYGON (((-73.93754 40.60856, -73.93830 ...
# 9   MULTIPOLYGON (((-73.90140 40.69159, -73.90189 ...
# 10  MULTIPOLYGON (((-73.97084 40.64638, -73.97077 ...
